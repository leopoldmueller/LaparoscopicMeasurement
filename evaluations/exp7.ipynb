# %%
import os

import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Direct Measurements

# %%
# Set pandas display options to show all rows
pd.set_option('display.max_rows', None)

ROOT = '..'

# %%
# Direct Offline Measurements

PATH_40_RAFT = 'datasets/evaluation/offline/on_surface/4cm/experiment_1681817246'

PATH_80_RAFT = 'datasets/evaluation/offline/on_surface/8cm/experiment_1681892890'

PATH_120_RAFT = 'datasets/evaluation/offline/on_surface/12cm/experiment_1681892056'

df_40_raft_results = pd.read_csv(os.path.join(ROOT, PATH_40_RAFT, 'results.csv'))

df_80_raft_results = pd.read_csv(os.path.join(ROOT, PATH_80_RAFT, 'results.csv'))

df_120_raft_results = pd.read_csv(os.path.join(ROOT, PATH_120_RAFT, 'results.csv'))

dataframes = {'df_40_raft_results': df_40_raft_results,
              'df_80_raft_results': df_80_raft_results,
              'df_120_raft_results': df_120_raft_results
              }

df_metrics = pd.DataFrame()

offline_errors = []

for key in dataframes:
    # Calculate absolute difference
    dataframes[key]['euclidian_diff'] = (dataframes[key]['euclidian'] - dataframes[key]['ground_truth'])

    # Calculate absolute difference
    dataframes[key]['on_surface_diff'] = (dataframes[key]['on_surface'] - dataframes[key]['ground_truth'])

    # Calculate absolute difference
    dataframes[key]['on_surface_spline_diff'] = (dataframes[key]['on_surface_spline'] - dataframes[key]['ground_truth'])


    offline_errors_direct = offline_errors + dataframes[key]['euclidian_diff'].to_list()

# %%
# Direct Online Measurements

PATH_40_RAFT = 'datasets/evaluation/online/on_surface/4cm/experiment_1682236165'

PATH_80_RAFT = 'datasets/evaluation/online/on_surface/8cm/experiment_1682237066'

PATH_120_RAFT = 'datasets/evaluation/online/on_surface/12cm/experiment_1682237843'

df_40_raft_results = pd.read_csv(os.path.join(ROOT, PATH_40_RAFT, 'results.csv'))

df_80_raft_results = pd.read_csv(os.path.join(ROOT, PATH_80_RAFT, 'results.csv'))

df_120_raft_results = pd.read_csv(os.path.join(ROOT, PATH_120_RAFT, 'results.csv'))

dataframes = {'df_40_raft_results': df_40_raft_results,
              'df_80_raft_results': df_80_raft_results,
              'df_120_raft_results': df_120_raft_results
              }

df_metrics = pd.DataFrame()

online_errors = []

for key in dataframes:
    # Calculate absolute difference
    dataframes[key]['euclidian_diff'] = (dataframes[key]['euclidian'] - dataframes[key]['ground_truth'])

    # Calculate absolute difference
    dataframes[key]['on_surface_diff'] = (dataframes[key]['on_surface'] - dataframes[key]['ground_truth'])

    # Calculate absolute difference
    dataframes[key]['on_surface_spline_diff'] = (dataframes[key]['on_surface_spline'] - dataframes[key]['ground_truth'])


    online_errors_direct = online_errors + dataframes[key]['euclidian_diff'].to_list()

# %% [markdown]
# # On-surface Offline Measurement

# %%
# On-surface online

# Set pandas display options to show all rows
pd.set_option('display.max_rows', None)

# Adjust ROOT to your repository directory
ROOT = '..'

# Set the experiment ids
PATH_40_RAFT = 'datasets/evaluation/offline/on_surface/4cm/experiment_1681817246'

PATH_80_RAFT = 'datasets/evaluation/offline/on_surface/8cm/experiment_1681892890'

PATH_120_RAFT = 'datasets/evaluation/offline/on_surface/12cm/experiment_1681892056'

PATH_WAVE_RAFT = 'datasets/evaluation/offline/on_surface/wave/experiment_1682179525'

PATH_CURVE_RAFT = 'datasets/evaluation/offline/on_surface/curve/experiment_1682180763'

PATH_TRIANGLE_RAFT = 'datasets/evaluation/offline/on_surface/triangle/experiment_1682180421'

# Read the measurement results
df_40_raft_results = pd.read_csv(os.path.join(ROOT, PATH_40_RAFT, 'results.csv'))

df_80_raft_results = pd.read_csv(os.path.join(ROOT, PATH_80_RAFT, 'results.csv'))

df_120_raft_results = pd.read_csv(os.path.join(ROOT, PATH_120_RAFT, 'results.csv'))

df_wave_raft_results = pd.read_csv(os.path.join(ROOT, PATH_WAVE_RAFT, 'results.csv'))

df_curve_raft_results = pd.read_csv(os.path.join(ROOT, PATH_CURVE_RAFT, 'results.csv'))

df_triangle_raft_results = pd.read_csv(os.path.join(ROOT, PATH_TRIANGLE_RAFT, 'results.csv'))

# Create a dictionary of the results
dataframes = {'df_40_raft_results': df_40_raft_results,
              'df_80_raft_results': df_80_raft_results,
              'df_120_raft_results': df_120_raft_results,
              'df_wave_raft_results': df_wave_raft_results,
              'df_curve_raft_results': df_curve_raft_results,
              'df_triangle_raft_results': df_triangle_raft_results
              }

# Initialize the metric dictionaries for each subplot
metrics_dict_on_surface = {}
metrics_dict_spline = {}

df_metrics_dict_on_surface = pd.DataFrame()
df_metrics_dict_spline = pd.DataFrame()

offline_errors_spline = []

offline_errors_basic = []

# Store all metrics in the specific dictionary
for key in dataframes:

    # Calculate errors
    dataframes[key]['on_surface_diff'] = dataframes[key]['on_surface'] - dataframes[key]['ground_truth']

    # Calculate errors
    dataframes[key]['on_surface_spline_diff'] = dataframes[key]['on_surface_spline'] - dataframes[key]['ground_truth']
    
    offline_errors_basic = offline_errors_basic + dataframes[key]['on_surface_diff'].to_list()
    offline_errors_spline = offline_errors_spline + dataframes[key]['on_surface_spline_diff'].to_list()

# %% [markdown]
# # On-surface Online Measurement

# %%
# On-surface online

# Set pandas display options to show all rows
pd.set_option('display.max_rows', None)

# Adjust ROOT to your repository directory
ROOT = '..'

# Set the experiment ids
PATH_40_RAFT = 'datasets/evaluation/online/on_surface/4cm/experiment_1682236165'

PATH_80_RAFT = 'datasets/evaluation/online/on_surface/8cm/experiment_1682237066'

PATH_120_RAFT = 'datasets/evaluation/online/on_surface/12cm/experiment_1682237843'

PATH_WAVE_RAFT = 'datasets/evaluation/online/on_surface/wave/experiment_1682248942'

PATH_CURVE_RAFT = 'datasets/evaluation/online/on_surface/curve/experiment_1682244954'

PATH_TRIANGLE_RAFT = 'datasets/evaluation/online/on_surface/triangle/experiment_1682245596'

# Read the measurement results
df_40_raft_results = pd.read_csv(os.path.join(ROOT, PATH_40_RAFT, 'results.csv'))

df_80_raft_results = pd.read_csv(os.path.join(ROOT, PATH_80_RAFT, 'results.csv'))

df_120_raft_results = pd.read_csv(os.path.join(ROOT, PATH_120_RAFT, 'results.csv'))

df_wave_raft_results = pd.read_csv(os.path.join(ROOT, PATH_WAVE_RAFT, 'results.csv'))

df_curve_raft_results = pd.read_csv(os.path.join(ROOT, PATH_CURVE_RAFT, 'results.csv'))

df_triangle_raft_results = pd.read_csv(os.path.join(ROOT, PATH_TRIANGLE_RAFT, 'results.csv'))

# Create a dictionary of the results
dataframes = {'df_40_raft_results': df_40_raft_results,
              'df_80_raft_results': df_80_raft_results,
              'df_120_raft_results': df_120_raft_results,
              'df_wave_raft_results': df_wave_raft_results,
              'df_curve_raft_results': df_curve_raft_results,
              'df_triangle_raft_results': df_triangle_raft_results
              }

# Initialize the metric dictionaries for each subplot
metrics_dict_on_surface = {}
metrics_dict_spline = {}

df_metrics_dict_on_surface = pd.DataFrame()
df_metrics_dict_spline = pd.DataFrame()

online_errors_spline = []

online_errors_basic = []

# Store all metrics in the specific dictionary
for key in dataframes:

    # Calculate errors
    dataframes[key]['on_surface_diff'] = dataframes[key]['on_surface'] - dataframes[key]['ground_truth']

    # Calculate errors
    dataframes[key]['on_surface_spline_diff'] = dataframes[key]['on_surface_spline'] - dataframes[key]['ground_truth']
    
    online_errors_basic = online_errors_basic + dataframes[key]['on_surface_diff'].to_list()
    online_errors_spline = online_errors_spline + dataframes[key]['on_surface_spline_diff'].to_list()

# %%
np.array(online_errors_basic).mean()
# Out:
# 1.5270716491307565

# %%
np.array(online_errors_spline).mean()
# Out:
# 0.4292887994818817

# %%
# Create Dataframe

df = pd.DataFrame(offline_errors_direct, columns=['Errors'])
df['Selection'] = 'Offline'
df['Type'] = 'Direct'

df = pd.DataFrame(offline_errors_direct, columns=['Errors'])
df['Selection'] = 'Offline'
df['Type'] = 'Direct'

df = pd.DataFrame(offline_errors_direct, columns=['Errors'])
df['Selection'] = 'Offline'
df['Type'] = 'Direct'


def create_dataframe(values, mode, selection):
    df = pd.DataFrame(values, columns=['Value'])
    df['Mode'] = mode
    df['Selection'] = selection
    return df

df_1 = create_dataframe(offline_errors_direct, 'Direct', 'Offline')

df_2 = create_dataframe(online_errors_direct, 'Direct', 'Online')

df_3 = create_dataframe(offline_errors_basic, 'Basic', 'Offline')

df_4 = create_dataframe(online_errors_basic, 'Basic', 'Online')

df_5 = create_dataframe(offline_errors_spline, 'Spline', 'Offline')

df_6 = create_dataframe(online_errors_spline, 'Spline', 'Online')

df = pd.concat([df_1, df_2, df_3, df_4, df_5, df_6], ignore_index=True)

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

# Draw a nested violinplot and split the violins for easier comparison
sns.violinplot(data=df, x="Mode", y="Value", hue="Selection",
               split=True, inner="quart", linewidth=1)
sns.despine(left=True)
# Out:
# /Users/leopoldmuller/Repositories/LaparoscopicMeasurement/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/leopoldmuller/Repositories/LaparoscopicMeasurement/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/leopoldmuller/Repositories/LaparoscopicMeasurement/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="whitegrid")
sns.set_context("paper")

# Create the plot
plt.figure(figsize=(6, 9))  # Adjust the size of the plot
sns.violinplot(data=df, 
x="Mode", y="Value", hue="Selection",
               split=True, inner="quart", linewidth=1.3, palette="pastel")  # I added the palette for a finer color distinction

# Adjust styles and labels
sns.despine(left=True)
plt.title('Comparison of Measurement Functionalities and Point Selection Types', fontsize=16)  # Add a title for the entire plot
plt.xlabel('Functionality', fontsize=14)  # Add a title for the x-axis
plt.ylabel('Error in mm', fontsize=14)  # Add a title for the y-axis
plt.legend(title='Type')  # Add a title to the legend

# Set y-axis limits and grid resolution
plt.ylim(-10, 10)
plt.yticks(np.arange(-10,11, 2))  # This will set y-ticks at intervals of 0.5 from -10 to 10

plt.show()  # Display the plot

# Save the figure
plt.savefig('measurements.pdf')
# Out:
# /Users/leopoldmuller/Repositories/LaparoscopicMeasurement/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/leopoldmuller/Repositories/LaparoscopicMeasurement/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/leopoldmuller/Repositories/LaparoscopicMeasurement/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="whitegrid")
sns.set_context("paper")

# Create the plot
plt.figure(figsize=(9, 9))  # Adjust the size of the plot
sns.violinplot(data=df, 
x="Mode", y="Value", hue="Selection",
               split=True, inner="quart", linewidth=1, palette=["#FF0B04", 'b'])  # I added the palette for a finer color distinction

# Adjust styles and labels
sns.despine(left=True)
#plt.title('Comparison of Measurement Functionalities and Point Selection Types', fontsize=16)  # Add a title for the entire plot
plt.xlabel('Functionality', fontsize=14)  # Add a title for the x-axis
plt.ylabel('Error in mm', fontsize=14)  # Add a title for the y-axis
plt.legend(title='Type')  # Add a title to the legend

# Set y-axis limits and grid resolution
plt.ylim(-7, 11)
plt.yticks(np.arange(-7,12, 1))  # This will set y-ticks at intervals of 0.5 from -10 to 10

plt.show()  # Display the plot

# Save the figure
plt.savefig('measurements.pdf')
# Out:
# /Users/leopoldmuller/Repositories/LaparoscopicMeasurement/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/leopoldmuller/Repositories/LaparoscopicMeasurement/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/leopoldmuller/Repositories/LaparoscopicMeasurement/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np  # Make sure to import numpy if you're using np.arange

# Set the style
sns.set_theme(style="whitegrid")
sns.set_context("paper")

# Set the font to Times New Roman
plt.rcParams["font.family"] = "Times New Roman"

# Create the plot
plt.figure(figsize=(9, 6))  # Adjust the size of the plot
sns.violinplot(data=df, 
               x="Mode", y="Value", hue="Selection",
               split=True, inner="quart", linewidth=1, palette=["#FF0B04", 'b'])

# Adjust styles and labels
sns.despine(left=True)
plt.xlabel('Functionality', fontsize=14)
plt.ylabel('Error in mm', fontsize=14)
plt.legend(title='Type')

# Set y-axis limits and grid resolution
plt.ylim(-7, 11)
plt.yticks(np.arange(-7, 12, 1))  # This will set y-ticks at intervals of 1 from -7 to 11

# The order of saving and showing is important
# Save the figure before plt.show()
plt.savefig('measurements.pdf', format='pdf')

# Display the plot
plt.show()
# Out:
# /Users/leopoldmuller/Repositories/LaparoscopicMeasurement/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/leopoldmuller/Repositories/LaparoscopicMeasurement/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/leopoldmuller/Repositories/LaparoscopicMeasurement/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="whitegrid")
sns.set_context("paper")

# Create the plot
plt.figure(figsize=(6, 9))  # Adjust the size of the plot
sns.violinplot(data=df, 
x="Mode", y="Value", hue="Selection",
               split=True, inner="quart", linewidth=1.3, palette="pastel")  # I added the palette for a finer color distinction

# Adjust styles and labels
sns.despine(left=True)
plt.title('Comparison of Measurement Functionalities and Point Selection Types', fontsize=16)  # Add a title for the entire plot
plt.xlabel('Functionality', fontsize=14)  # Add a title for the x-axis
plt.ylabel('Error in mm', fontsize=14)  # Add a title for the y-axis
plt.legend(title='Type')  # Add a title to the legend

# Set y-axis limits and grid resolution
plt.ylim(-10, 10)
plt.yticks(np.arange(-10,11, 2))  # This will set y-ticks at intervals of 0.5 from -10 to 10

plt.show()  # Display the plot

# Save the figure
plt.savefig('measurements.pdf')
# Out:
# /Users/leopoldmuller/Repositories/LaparoscopicMeasurement/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/leopoldmuller/Repositories/LaparoscopicMeasurement/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/leopoldmuller/Repositories/LaparoscopicMeasurement/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
# print the categories of column 'Type' in df
print(df['Selection'].unique())
# print the frequency of each category
print(df['Selection'].value_counts())
# Out:
# ['Offline' 'Online']
# Selection
# Offline    624
# Online     624
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np  # Make sure to import numpy if you're using np.arange

# Set the style
sns.set_theme(style="whitegrid")
sns.set_context("paper")

# Set the font to Times New Roman
plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["font.size"] = 12  # You can set a base font size here

# Create the plot
plt.figure(figsize=(10, 6))
sns.violinplot(data=df, 
               x="Mode", y="Value", hue="Selection",
               split=True, inner="quart", linewidth=1, palette=["#FF0B04", 'b'])

# Adjust styles and labels
sns.despine(left=True)
plt.xlabel('Functionality', fontsize=14)  # You can specify font size here for axis labels
plt.ylabel('Error in mm', fontsize=14)

# Increase the size of the axis values (ticks)
plt.xticks(fontsize=12)  # Set the x-ticks with increased font size
plt.yticks(fontsize=12)  # Set the y-ticks with increased font size

plt.legend(title='Type', fontsize=14)  # You can also adjust the legend font size

# Set y-axis limits and grid resolution
plt.ylim(-7, 11)
plt.yticks(np.arange(-7, 12, 1))

# Save the figure before plt.show()
plt.savefig('measurements.pdf', format='pdf')

# Display the plot
plt.show()
# Out:
# /Users/leopoldmuller/Repositories/LaparoscopicMeasurement/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/leopoldmuller/Repositories/LaparoscopicMeasurement/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/leopoldmuller/Repositories/LaparoscopicMeasurement/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
